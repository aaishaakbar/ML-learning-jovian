# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('train.csv')
print(df.shape)
print(df.head())
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
x= df[['GrLivArea']]   # feature
y = df['SalePrice']     # target

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
print("coefficient:", model.coef_)
print("intercept:", model.intercept_)
# Out:
# coefficient: [102.48895892]
# intercept: 24899.748157338123

# %%
y_pred = model.predict(x_test)

# Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.5542632452871118
# RMSE: 58471.756525529534

# %%
y_pred = model.predict(x_test)

# Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.5542632452871118
# RMSE: 58471.756525529534

# %%
plt.scatter(x_test, y_test, color="blue", label="Actual")
plt.scatter(x_test, y_pred, color="red", label="Predicted")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.legend()
plt.show()

# %%
x = df[['GrLivArea', 'OverallQual']]
y= df['SalePrice']

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
print("coefficient:", model.coef_)
print("intercept:", model.intercept_)
# Out:
# coefficient: [   53.14476646 32523.65736394]
# intercept: -98827.87520677995

# %%
y_pred = model.predict(x_test)

# Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7457643057171447
# RMSE: 44159.604942302176

# %%
y_pred = model.predict(x_test)

# Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7457643057171447
# RMSE: 44159.604942302176

# %%
plt.scatter(y_test, y_pred, color="blue", alpha=0.6)
plt.xlabel("Actual SalePrice")
plt.ylabel("Predicted SalePrice")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter for 'GrLivArea'
plt.scatter(df['GrLivArea'], df['SalePrice'])
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# Scatter for 'OverallQual'
plt.scatter(df['OverallQual'], df['SalePrice'])
plt.xlabel('OverallQual')
plt.ylabel('SalePrice')
plt.show()

# %%
new_houses = pd.DataFrame({
    'GrLivArea': [1500, 2500],
    'OverallQual': [7, 8]
})
predictions = model.predict(new_houses)
print(predictions)
# Out:
# [208554.87603154 294223.29985597]
